# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#    TRADE ID SOURCE_SYSTEM          TRADE_DATE ANOMALY
# 0         1             A 2023-01-10 09:00:00       N
# 1         2             A 2023-01-11 09:15:00       N
# 2         3             A 2023-01-10 09:00:00       N
# 3         4             A 2023-01-11 09:15:00       N
# 4         5             A 2023-01-17 09:30:00       N

# %%
# df['TRADE_DATE'] = pd.to_datetime(df['TRADE_DATE'])

# %%
df.head(10)
# Out:
#    TRADE ID SOURCE_SYSTEM          TRADE_DATE ANOMALY
# 0         1             A 2023-01-10 09:00:00       N
# 1         2             A 2023-01-11 09:15:00       N
# 2         3             A 2023-01-10 09:00:00       N
# 3         4             A 2023-01-11 09:15:00       N
# 4         5             A 2023-01-17 09:30:00       N
# 5         6             A 2023-01-18 09:45:00       N
# 6         7             A 2023-01-21 11:45:00       N
# 7         8             A 2023-01-25 22:37:00       Y
# 8         9             A 2023-01-26 10:40:00       N
# 9        10             A 2023-02-01 12:00:00       N

# %%
df['TRADE_YEAR'] = df['TRADE_DATE'].dt.year
df['TRADE_MONTH'] = df['TRADE_DATE'].dt.month
df['TRADE_DAY'] = df['TRADE_DATE'].dt.day
df['TRADE_HOUR'] = df['TRADE_DATE'].dt.hour
df['TRADE_MINUTE'] = df['TRADE_DATE'].dt.minute
df.head()
# Out:
#    TRADE ID SOURCE_SYSTEM          TRADE_DATE ANOMALY  TRADE_YEAR  \
# 0         1             A 2023-01-10 09:00:00       N        2023
# 1         2             A 2023-01-11 09:15:00       N        2023
# 2         3             A 2023-01-10 09:00:00       N        2023
# 3         4             A 2023-01-11 09:15:00       N        2023
# 4         5             A 2023-01-17 09:30:00       N        2023
#
#    TRADE_MONTH  TRADE_DAY  TRADE_HOUR  TRADE_MINUTE
# 0            1         10           9             0
# 1            1         11           9            15
# 2            1         10           9             0
# 3            1         11           9            15
# 4            1         17           9            30

# %%
#df = df.drop(['TRADE ID','TRADE_DATE','SOURCE_SYSTEM','TRADE_MINUTE','TRADE_YEAR'], axis=1)

# %%
df.head()
# Out:
#   ANOMALY  TRADE_MONTH  TRADE_DAY  TRADE_HOUR
# 0       N            1         10           9
# 1       N            1         11           9
# 2       N            1         10           9
# 3       N            1         11           9
# 4       N            1         17           9

# %%
#df.plot(x='TRADE_HOUR',y=['TRADE_DAY','TRADE_MONTH'])

# %%
sns.pairplot(df,hue='ANOMALY',palette='rainbow')
# Out:
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df)

# %%
a= sns.PairGrid(df)
a.map(plt.scatter)

# %%
sns.pairplot(df,hue='TRADE_HOUR',palette='rainbow')
# Out:
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Deepthi\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.JointGrid(x="TRADE_MONTH", y="TRADE_HOUR", data=df)
g = g.plot(sns.regplot, sns.distplot)

# %%
g = sns.FacetGrid(df,hue='TRADE_HOUR')
# Notice hwo the arguments come after plt.scatter call
g = g.map(plt.scatter, "TRADE_MONTH", "TRADE_HOUR").add_legend()
